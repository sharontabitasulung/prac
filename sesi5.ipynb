# %% [markdown]
# Pandas

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("nbaallelo.csv")

# %%
#seberapa besar datanya
df.shape
# Out:
# (126314, 23)

# %%
len(df)
# Out:
# 126314

# %%
#lihat data
#menampilkan semua kolom
pd.set_option("display.max.columns",None)
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  pts      elo_i      elo_n  win_equiv  \
# 0            0     TRH       Huskies   66  1300.0000  1293.2767  40.294830
# ...

# %%
pd.set_option("display.max.columns",None)
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126304          98            1     CLE  Cavaliers   95  1708.1705  1716.8708
# ...

# %%
#menampilkan info setiap columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
#stat description sederhana
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# ### Eksplorasi DATA [EDA]

# %%
# lihat team.id yang sering muncul beserta jumlahnya
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.team_id.value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
# save kedalam file
df["team_id"].value_counts().to_csv('team_id.csv')

# %%
df.fran_id.value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
#query sederhana
kondisi = df["fran_id"] == "Lakers"
df[kondisi]["team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
#konversi kolom dengan tipe data waktu
df["date_game"]=pd.to_datetime(df["date_game"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
#query waktu
kondisi=df["date_game"].dt.day==3
kondisi2 = df["date_game"].dt.month==11
df[kondisi & kondisi2].head(10)
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 10            6  194611030CLR   NBA        1     1947 1946-11-03           2
# 11            6  194611030CLR   NBA        0     1947 1946-11-03           1
# 1132        567  194811030FTW   NBA        0     1949 1948-11-03           1
# 1133        567  194811030FTW   NBA        1     1949 1948-11-03           1
# 1134        568  194811030WSC   NBA        1     1949 1948-11-03           1
# 1135        568  194811030WSC   NBA        0     1949 1948-11-03           1
# 1906        954  194911030AND   NBA        0     1950 1949-11-03           1
# 1907        954  194911030AND   NBA        1     1950 1949-11-03           3
# 1908        955  194911030BLB   NBA        1     1950 1949-11-03           2
# 1909        955  194911030BLB   NBA        0     1950 1949-11-03           2
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# ...

# %%
kondisi = df["team_id"] == "MNL"
df[kondisi]['date_game'].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %%
df.loc[df["team_id"]== "MNL", "date_game"].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %%
df[kondisi]['date_game'].max()
# Out:
# Timestamp('1960-03-26 00:00:00')

# %%
# agregasi
kondisi = df["team_id"] == "MNL"
df[kondisi]["date_game"].agg(('min','max'))
#df.loc[df['team_id']== 'MNL', 'date_game']
# Out:
# min   1948-11-04
# max   1960-03-26
# Name: date_game, dtype: datetime64[ns]

# %%
kondisi = df['team_id']== 'MNL'
df[kondisi]['win_equiv'].agg(('min','max','mean'))
# Out:
# min     24.525501
# max     66.217308
# mean    45.702914
# Name: win_equiv, dtype: float64

# %% [markdown]
# ### DEEP DIVE TO PANDAS

# %%
# tipe data series
data = [0, 0.25, 0.5, 0.75, 1]
np_data = np.array(data)
ser_data = pd.Series(data)

# %%
data
# Out:
# [0, 0.25, 0.5, 0.75, 1]

# %%
np_data
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
ser_data
# Out:
# 0    0.00
# 1    0.25
# 2    0.50
# 3    0.75
# 4    1.00
# dtype: float64

# %%
ser_data[3]
# Out:
# 0.75

# %%
np_data [-1]
# Out:
# 1.0

# %%
ser_data.values
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
ser_data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser_data_idx = pd.Series(data, index= ['a','b','c','d','e'])
ser_data_idx
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
my_dict = {'kaset':100000,
            'cd': 50000,
            'dvd': 200000}
ser_dict = pd.Series(my_dict)
ser_dict
# Out:
# kaset    100000
# cd        50000
# dvd      200000
# dtype: int64

# %%
#dataframe
nilai = [[76, 90, 77, 98],
        [90, 80, 78,68],
        [80, 68, 98 ,99]]#matematika,ipa,bind,bing
df = pd.DataFrame(nilai, 
                    columns= ['matematika', 'ipa', 'bind','bing'],
                    index=['Budi','Anggun','Cita'])
df
# Out:
#         matematika  ipa  bind  bing
# Budi            76   90    77    98
# Anggun          90   80    78    68
# Cita            80   68    98    99

# %%
np_nilai = np.array(nilai)
np_nilai
# Out:
# array([[76, 90, 77, 98],
#        [90, 80, 78, 68],
#        [80, 68, 98, 99]])

# %%
df['matematika']['Budi']
# Out:
# 76

# %%
df.loc['Budi']
# Out:
# matematika    76
# ipa           90
# bind          77
# bing          98
# Name: Budi, dtype: int64

# %%
#LOC and ILOC
ser_data_idx = pd.Series(data, index= ['a','b','c','d','e'])
ser_data_idx
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
# menggunakan loc
ser_data_idx.loc['c']
# Out:
# 0.5

# %%
ser_data_idx.loc['a':'c']
# Out:
# a    0.00
# b    0.25
# c    0.50
# dtype: float64

# %%
#menggunakan explisit index
ser_data_idx.iloc[1:3]
# Out:
# b    0.25
# c    0.50
# dtype: float64

# %%
#dataframe
nilai = [[76, 90, 77, 98],
        [90, 80, 78,68],
        [80, 68, 98 ,99]]#matematika,ipa,bind,bing
df = pd.DataFrame(nilai, 
                    columns= ['matematika', 'ipa', 'bind','bing'],
                    index=['Budi','Anggun','Cita'])
df
# Out:
#         matematika  ipa  bind  bing
# Budi            76   90    77    98
# Anggun          90   80    78    68
# Cita            80   68    98    99

# %%
df.loc['Budi','matematika']
# Out:
# 76

# %%
df.iloc[2,1]
# Out:
# 68

# %%
df.loc['Budi':'Cita','ipa':'bind']
# Out:
#         ipa  bind
# Budi     90    77
# Anggun   80    78
# Cita     68    98

# %%
df.iloc[1:3, 1:3]
# Out:
#         ipa  bind
# Anggun   80    78
# Cita     68    98

# %% [markdown]
# ### QUERY SEDERHANA

# %%
df=pd.read_csv("nbaallelo.csv")
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
# kueri kondisi
kondisi= df['pts'] > 60
df[kondisi]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 11              6  194611030CLR   NBA        0     1947  11/3/1946
# 13              7  194611040PIT   NBA        1     1947  11/4/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
kondisi = df ['year_id']> 2010
df_carr_decade =df[kondisi]

# %%
df_carr_decade.head()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
#
#         seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 113656           1            0     MIA     Heat   80  1547.3638  1543.1600
# 113657           1            0     BOS  Celtics   88  1625.0994  1629.3031
# 113658           1            0     HOU  Rockets  110  1504.1956  1502.5969
# 113659           1            0     LAL   Lakers  112  1647.6016  1649.2002
# 113660           1            0     PHO     Suns   92  1643.0225  1630.6204
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
kondisi = df['notes'].notnull()
df_with_notes = df[kondisi]
df_with_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5424 entries, 930 to 124863
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gameorder      5424 non-null   int64
#  1   game_id        5424 non-null   object
#  2   lg_id          5424 non-null   object
#  3   _iscopy        5424 non-null   int64
#  4   year_id        5424 non-null   int64
#  5   date_game      5424 non-null   object
#  6   seasongame     5424 non-null   int64
#  7   is_playoffs    5424 non-null   int64
#  8   team_id        5424 non-null   object
#  9   fran_id        5424 non-null   object
#  10  pts            5424 non-null   int64
#  11  elo_i          5424 non-null   float64
#  12  elo_n          5424 non-null   float64
#  13  win_equiv      5424 non-null   float64
#  14  opp_id         5424 non-null   object
#  15  opp_fran       5424 non-null   object
#  16  opp_pts        5424 non-null   int64
# ...

# %%
kondisi = df['fran_id'].str.endswith('ers')
df [kondisi]['fran_id'].value_counts()
# Out:
# Lakers          6024
# Sixers          5644
# Pacers          4227
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Bombers          249
# Steamrollers     168
# Packers           72
# Name: fran_id, dtype: int64

# %%
kondisi1 = df['fran_id'] == 'Spurs'
kondisi2 = df['year_id'] > 2010

df[kondisi1 & kondisi2]['game_result'].value_counts()
# Out:
# W    332
# L    133
# Name: game_result, dtype: int64

# %%
df[kondisi1 & kondisi2].groupby(['year_id','game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64
